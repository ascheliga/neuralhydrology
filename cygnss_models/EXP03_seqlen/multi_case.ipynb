# %%
import pickle
from pathlib import Path
import os

import matplotlib.pyplot as plt
import pandas as pd
import torch
from neuralhydrology.evaluation import metrics, eval_wrapper
from neuralhydrology.nh_run import start_run, eval_run

# %%
all_runs_dir = '/global/home/users/ann_scheliga/neuralhydrology/runs/'
exp_name ='EXP03_general'

# %% [markdown]
# ### Evaluate run on test set
# Change the `run_dir` argument by grabbing from:
# 1. above training output log
# 2. below list of runs

# %%
all_runs = os.listdir(all_runs_dir)
exp_runs = [run for run in all_runs if exp_name in run]
exp_runs.sort()
exp_runs
# Out:
# ['EXP03_general_no_sw_seqlen_10_1208_181648',
#  'EXP03_general_no_sw_seqlen_30_1208_181706',
#  'EXP03_general_no_sw_seqlen_60_1208_181726',
#  'EXP03_general_no_sw_seqlen_90_1208_181748',
#  'EXP03_general_wi_sw_seqlen_10_1208_181520',
#  'EXP03_general_wi_sw_seqlen_30_1208_181540',
#  'EXP03_general_wi_sw_seqlen_60_1208_181600',
#  'EXP03_general_wi_sw_seqlen_90_1208_181623']

# %%
crb_10day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_10_1208_181648',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_10_1208_181520',
    run_dir = all_runs_dir,
    basin_key = '4152450')
# Out:
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_10_1208_181520
# ...
# # Validation: 100%|██████████| 2/2 [00:00<00:00,  8.17it/s]
# Evaluation complete of /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_10_1208_181520
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_no_sw_seqlen_10_1208_181648
# # Evaluation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# ...
# # Evaluation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# ...
# # Validation: 100%|██████████| 2/2 [00:00<00:00,  7.71it/s]
# ...

# %%
crb_30day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_30_1208_181706',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_30_1208_181540',
    run_dir = all_runs_dir,
    basin_key = '4152450')
# Out:
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_30_1208_181540
# ...
# # Evaluation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# ...
# # Validation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# # Validation: 100%|██████████| 2/2 [00:00<00:00, 22.12it/s]
# Evaluation complete of /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_30_1208_181540
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_no_sw_seqlen_30_1208_181706
# ...

# %%
crb_60day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_60_1208_181726',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_60_1208_181600',
    run_dir = all_runs_dir,
    basin_key = '4152450')
# Out:
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_60_1208_181600
# ...
# # Validation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# # Validation: 100%|██████████| 2/2 [00:00<00:00, 20.20it/s]
# Evaluation complete of /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_60_1208_181600
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_no_sw_seqlen_60_1208_181726
# # Evaluation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# ...

# %%
crb_90day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_90_1208_181748',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_90_1208_181623',
    run_dir = all_runs_dir,
    basin_key = '4152450')
# Out:
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_90_1208_181623
# ...
# # Validation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# # Validation: 100%|██████████| 2/2 [00:00<00:00, 10.62it/s]
# Evaluation complete of /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_90_1208_181623
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_no_sw_seqlen_90_1208_181748
# ...
# # Validation: 100%|██████████| 2/2 [00:00<00:00,  2.14it/s]
# Evaluation complete of /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_no_sw_seqlen_90_1208_181748
# dict_keys(['1834101', '4152450'])
# dict_keys(['1834101', '4152450'])
# dict_keys(['1834101', '4152450'])
# dict_keys(['1834101', '4152450'])
# Loaded model results

# %%
kainji_10day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_10_1208_181648',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_10_1208_181520',
    run_dir = all_runs_dir,
    basin_key = '1834101')
kainji_30day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_30_1208_181706',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_30_1208_181540',
    run_dir = all_runs_dir,
    basin_key = '1834101')
kainji_60day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_60_1208_181726',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_60_1208_181600',
    run_dir = all_runs_dir,
    basin_key = '1834101')
kainji_90day_metrics = eval_wrapper.quick_eval(fp_no_sw='EXP03_general_no_sw_seqlen_90_1208_181748',
    fp_wi_sw='EXP03_general_wi_sw_seqlen_90_1208_181623',
    run_dir = all_runs_dir,
    basin_key = '1834101')
# Out:
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_10_1208_181520
# # Evaluation:   0%|          | 0/2 [00:00<?, ?it/s][PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/1834101_kainji.pkl')]
# [PosixPath('/global/scratch/users/ann_scheliga/basin_forcing_processed/4152450_glen_canyon.pkl')]
# ...
# # Validation: 100%|██████████| 2/2 [00:00<00:00,  8.64it/s]
# Evaluation complete of /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_wi_sw_seqlen_10_1208_181520
# /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_no_sw_seqlen_10_1208_181648
# ...
# # Validation: 100%|██████████| 2/2 [00:00<00:00,  7.96it/s]
# Evaluation complete of /global/home/users/ann_scheliga/neuralhydrology/runs/EXP03_general_no_sw_seqlen_10_1208_181648
# dict_keys(['1834101', '4152450'])
# dict_keys(['1834101', '4152450'])
# dict_keys(['1834101', '4152450'])
# dict_keys(['1834101', '4152450'])
# Loaded model results
# ...
