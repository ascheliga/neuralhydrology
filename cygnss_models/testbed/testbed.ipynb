# %%
import yaml
from ruamel.yaml import YAML
from pathlib import Path

# %%
yml_path = Path('testbed.yml')

# %%
with open(yml_path) as f:
    dataMap = yaml.safe_load(f)

# %%
dataMap
# Out:
# {'grdc_id': 1834101,
#  'grdc_sub_ids': [1834110],
#  'dam_name': 'kainji',
#  'start_year': 2018,
#  'stop_year_ex': 2024,
#  'basin_str': 'niger'}

# %%
with yml_path.open('r') as fp:
    yaml = YAML(typ="safe")
    cfg = yaml.load(fp)

# %%
dataMap['grdc_sub_ids']
# Out:
# [1834110]
